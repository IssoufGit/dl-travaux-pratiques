# %% [markdown]
# # Comparaison du CNN et MLP sur le Cifar10 dataset.

# %% [markdown]
# ### <font color='blue'>Importer les libraries et initialser une carte graphique (GPU) </font>

# %%
# Importer les libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split

import numpy as np
import matplotlib.pyplot as plt

# Reproductibilité
torch.manual_seed(42)

# %% [markdown]
# ### <font color='blue'> Charger et explorer le jeu de données. Choisir un nombre limité de données pour l'entrainement. </font>

# %%
# Chargement via torchvision (équivalent de tf.keras.datasets.cifar10): 
# Pour comprendre plus sur ces données veillez visiter ce lien: https://www.cs.toronto.edu/~kriz/cifar.html
from torchvision.transforms import v2
from torchvision import datasets

transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True), # Scale = True fait un mapping [0, 255] --> [0, 1]
    #v2.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Pour plus de details sur l'operation de normalisation, voir: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.v2.Normalize.html#torchvision.transforms.v2.Normalize

train_full = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

print(f'Taille train complet : {len(train_full)}')
print(f'Taille test          : {len(test_set)}')
# Out:
# /Users/iouattara/dev-space/uvbf/uvbf-dl/.venv/lib/python3.12/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Taille train complet : 50000
# Taille test          : 10000

# %%
# Chacune des sets, en plus des images, contient aussi les étiquettes
print(f'X_train shape : {train_full.data.shape}')
print(f'Y_train shape : {len(train_full.targets)}') # Une liste
# Out:
# X_train shape : (50000, 32, 32, 3)
# Y_train shape : 50000

# %%
# Explorer le jeu de donnée
index_img = 505
plt.imshow(train_full.data[index_img,:,:])
plt.title('Ceci est l\'image de: '+str(train_full.targets[index_img]))
# Out:
# Text(0.5, 1.0, "Ceci est l'image de: 4")

# %%
# Split train / validation
# Il faut noter ici que PyTorch ne produit pas une copie des données, mais extrait uniquement les indices pour le train_set 
# et les indices pour le validation set.
validation_split=0.2
n_total = len(train_full)         
n_val   = int(validation_split * n_total)             
n_train = n_total - n_val                 

train_set, val_set = random_split(
    train_full,
    [n_train, n_val],
    generator=torch.Generator().manual_seed(42)
)

print(f'Train : {len(train_set)}  |  Validation : {len(val_set)}')
# Out:
# Train : 40000  |  Validation : 10000

# %%
# Choisir un nombre limité d'image pour votre entrainement (les 40000 images peuvent prendre
# trop de temps)

from torch.utils.data import Subset

num_train_img = 40000

# On prend les num_train_img premiers indices du train_set déjà splitté
train_set_reduit = Subset(
    train_set.dataset,
    train_set.indices[:num_train_img]
)

print(f'Train réduit : {len(train_set_reduit)}  |  Validation : {len(val_set)}')
# Out:
# Train réduit : 40000  |  Validation : 10000

# %% [markdown]
# ### <font color='blue'> Definir une fonction utilitaire pour plotter l'historique de l'entrainement. </font>

# %%
# Une fonction qui va permettre de plotter la fonction de cout et la performance
def plot_training_history(history, save_fig=False, fig_name=''):
    # Plot training & validation accuracy values
    plt.figure()
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    if save_fig:
        plt.savefig('accuracy' + fig_name + '.png')
    plt.show()

    plt.figure()
    # Plot training & validation loss values
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    if save_fig:
        plt.savefig('loss' + fig_name+ '.png')
    plt.show()

# %% [markdown]
# ### <font color='blue'> Definir une fonction utilitaire pour faire de la prediction avec le modèle </font>

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

def model_predict(model, img: torch.Tensor, true_label: int) -> None:
    """
    Affiche une image CIFAR-10 et la prédiction du modèle.

    Paramètres
    ----------
    model      : nn.Module        — modèle entraîné
    img        : Tensor (3,32,32) — image issue du Dataset (format PyTorch CHW)
    true_label : int              — label correct
    """
    device = next(model.parameters()).device

    # Affichage
    # plt.imshow attend (H, W, C) — on permute les axes CHW → HWC
    plt.imshow(img.permute(1, 2, 0))
    plt.axis('off')
    plt.show()

    # Prédiction
    # np.expand_dims(img, 0) → unsqueeze(0) : (3,32,32) → (1,3,32,32)
    model.eval()
    with torch.no_grad():
        logits = model(img.unsqueeze(0).to(device))
        y_hat  = logits.argmax(dim=1).item()

    print(f"The image is a      : {class_names[true_label]}")
    print(f"The model predicted : {class_names[y_hat]}")

# %% [markdown]
# ### <font color='blue'> Definir une fonction utilitaire pour entrainer le modèle <font>

# %%
from torch.utils.data import DataLoader


def train_net(model, train_dataset, val_dataset,
              num_epochs, lr, batch_size,
              device=None,
              weight_decay=1e-6):
    """
    Entraîne un modèle PyTorch et retourne le modèle et l'historique.

    Paramètres
    ----------
    model         : nn.Module — modèle déjà instancié
    train_dataset : Dataset   — sous-ensemble d'entraînement
    val_dataset   : Dataset   — sous-ensemble de validation
    num_epochs    : int       — nombre d'époques
    lr            : float     — taux d'apprentissage (AdamW)
    batch_size    : int       — taille des mini-batches
    device        : torch.device | None — auto-détecté si None
    weight_decay  : float     — weight decay découplé (AdamW)

    Retours
    -------
    model   : nn.Module — modèle entraîné
    history : dict      — clés 'loss', 'accuracy', 'val_loss', 'val_accuracy'
    """

    # detecter et utiliser l'accelerateur pour votre machine
    if device == None:
        device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
    print(f"Using {device} device")
    model = model.to(device)

    # DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)

    # Optimiseur et fonction de coût 
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = torch.nn.CrossEntropyLoss()

    history = {'loss': [], 'accuracy': [], 'val_loss': [], 'val_accuracy': []}

    # Chaque pas d'entraînement comprent une étape d'entraînement et une étape de validation
    for epoch in range(num_epochs):

        # Phase entraînement
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            logits = model(X_batch)
            loss   = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * X_batch.size(0)
            correct      += (logits.argmax(dim=1) == y_batch).sum().item()
            total        += X_batch.size(0)

        train_loss = running_loss / total
        train_acc  = correct / total

        # Phase validation
        model.eval()
        val_loss_sum, val_correct, val_total = 0.0, 0, 0

        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                logits        = model(X_batch)
                val_loss_sum += criterion(logits, y_batch).item() * X_batch.size(0)
                val_correct  += (logits.argmax(dim=1) == y_batch).sum().item()
                val_total    += X_batch.size(0)

        val_loss = val_loss_sum / val_total
        val_acc  = val_correct  / val_total

        history['loss'].append(train_loss)
        history['accuracy'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_accuracy'].append(val_acc)

        print(f'Epoch {epoch+1:3d}/{num_epochs}  '
              f'loss={train_loss:.4f}  acc={train_acc:.4f}  '
              f'val_loss={val_loss:.4f}  val_acc={val_acc:.4f}')

    return model, history

# %%
def evaluate(model: nn.Module, dataset,
             device=None, batch_size: int = 256) -> tuple:
    """
    Évalue un modèle sur un Dataset complet.
    Équivalent de model.evaluate() en Keras.

    Retourne (loss, accuracy).
    """
    if device is None:
        device = next(model.parameters()).device   # même device que le modèle

    loader    = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    criterion = nn.CrossEntropyLoss()

    model.eval()
    total_loss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            logits      = model(X_batch)
            total_loss += criterion(logits, y_batch).item() * X_batch.size(0)
            correct    += (logits.argmax(dim=1) == y_batch).sum().item()
            total      += X_batch.size(0)

    loss = total_loss / total
    acc  = correct   / total
    print(f'loss={loss:.4f}  accuracy={acc:.4f}')
    return loss, acc

# %% [markdown]
# ### <font color='blue'> Definir un modèle MLP </font

# %%
class MLP(nn.Module):
    """
    Multi-Layer Perceptron pour la classification MNIST.
    Architecture
    ------------
    Input (N, 28, 28) → Flatten → [Linear → ReLU] × 2 → Linear (logits)
    """

    def __init__(self, input_dim: int = 784,
                 num_classes: int = 10) -> None:
        super().__init__()

        self.classifier = nn.Sequential(
            nn.Flatten(),                        # (N, 28, 28) → (N, 784)
            nn.Linear(input_dim, 64),            # (N, 784)   → (N, 64)
            nn.ReLU(),
            nn.Linear(64, 32),                   # (N, 64)    → (N, 32)
            nn.ReLU(),
            nn.Linear(32, num_classes),          # (N, 32)    → (N, 10) logits
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.classifier(x)

# %%
# Visualiser le modèle
# Instanciation et affichage
sample_x, _ = train_set_reduit[0]          # (3, 32, 32) pour CIFAR-10
input_dim   = sample_x.numel()      # 3 × 32 × 32 = 3072

model_mlp = MLP(input_dim=input_dim, num_classes=10)
print(model_mlp)

n_params = sum(p.numel() for p in model_mlp.parameters() if p.requires_grad)
print(f'\nParamètres entraînables : {n_params:,}')
# Out:
# MLP(
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3072, out_features=64, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
#
# Paramètres entraînables : 199,082

# %% [markdown]
# ### <font color='blue'> Entrainer et tester le modèle. </font>

# %%
# Entrainer le modèle
nombre_epochs =300
batch_size = 64
lr = 0.01
mlp_trained, history= train_net(model_mlp, train_set_reduit, val_set, nombre_epochs, lr, batch_size, None)
# Out:
# Using mps device
# Epoch   1/300  loss=1.8969  acc=0.3110  val_loss=1.8294  val_acc=0.3404
# Epoch   2/300  loss=1.8113  acc=0.3392  val_loss=1.8280  val_acc=0.3263
# Epoch   3/300  loss=1.7808  acc=0.3515  val_loss=1.7973  val_acc=0.3264
# Epoch   4/300  loss=1.7350  acc=0.3677  val_loss=1.7386  val_acc=0.3695
# Epoch   5/300  loss=1.7031  acc=0.3848  val_loss=1.8084  val_acc=0.3399
# Epoch   6/300  loss=1.6682  acc=0.4001  val_loss=1.7710  val_acc=0.3706
# Epoch   7/300  loss=1.6568  acc=0.4010  val_loss=1.7727  val_acc=0.3487
# Epoch   8/300  loss=1.6348  acc=0.4118  val_loss=1.7322  val_acc=0.3790
# Epoch   9/300  loss=1.6144  acc=0.4183  val_loss=1.7632  val_acc=0.3854
# Epoch  10/300  loss=1.5917  acc=0.4291  val_loss=1.7222  val_acc=0.4040
# Epoch  11/300  loss=1.5825  acc=0.4310  val_loss=1.7451  val_acc=0.3995
# Epoch  12/300  loss=1.5596  acc=0.4390  val_loss=1.7678  val_acc=0.3793
# Epoch  13/300  loss=1.5504  acc=0.4410  val_loss=1.6829  val_acc=0.4088
# Epoch  14/300  loss=1.5280  acc=0.4505  val_loss=1.7205  val_acc=0.4096
# Epoch  15/300  loss=1.5204  acc=0.4522  val_loss=1.7419  val_acc=0.3863
# Epoch  16/300  loss=1.5023  acc=0.4596  val_loss=1.7251  val_acc=0.4216
# Epoch  17/300  loss=1.4977  acc=0.4627  val_loss=1.7188  val_acc=0.3965
# Epoch  18/300  loss=1.4741  acc=0.4692  val_loss=1.7065  val_acc=0.4169
# Epoch  19/300  loss=1.4688  acc=0.4679  val_loss=1.7302  val_acc=0.4089
# Epoch  20/300  loss=1.4782  acc=0.4706  val_loss=1.7100  val_acc=0.4284
# Epoch  21/300  loss=1.4520  acc=0.4797  val_loss=1.7194  val_acc=0.4179
# Epoch  22/300  loss=1.4401  acc=0.4812  val_loss=1.7561  val_acc=0.4177
# Epoch  23/300  loss=1.4267  acc=0.4863  val_loss=1.7515  val_acc=0.4170
# Epoch  24/300  loss=1.4272  acc=0.4876  val_loss=1.7929  val_acc=0.3937
# Epoch  25/300  loss=1.4139  acc=0.4875  val_loss=1.7832  val_acc=0.4215
# Epoch  26/300  loss=1.4115  acc=0.4909  val_loss=1.7737  val_acc=0.4167
# Epoch  27/300  loss=1.4056  acc=0.4920  val_loss=1.7989  val_acc=0.4027
# Epoch  28/300  loss=1.3995  acc=0.4922  val_loss=1.7855  val_acc=0.4205
# Epoch  29/300  loss=1.3837  acc=0.4976  val_loss=1.8619  val_acc=0.3920
# Epoch  30/300  loss=1.3869  acc=0.4995  val_loss=1.8360  val_acc=0.4098
# Epoch  31/300  loss=1.3719  acc=0.5036  val_loss=1.8238  val_acc=0.4131
# Epoch  32/300  loss=1.3867  acc=0.5011  val_loss=1.8028  val_acc=0.4107
# Epoch  33/300  loss=1.3675  acc=0.5061  val_loss=1.8345  val_acc=0.4044
# Epoch  34/300  loss=1.3445  acc=0.5108  val_loss=1.8595  val_acc=0.4123
# Epoch  35/300  loss=1.3406  acc=0.5125  val_loss=1.9765  val_acc=0.3906
# Epoch  36/300  loss=1.3519  acc=0.5095  val_loss=1.8681  val_acc=0.4130
# Epoch  37/300  loss=1.3379  acc=0.5163  val_loss=1.9281  val_acc=0.4212
# Epoch  38/300  loss=1.3283  acc=0.5158  val_loss=1.9141  val_acc=0.4135
# Epoch  39/300  loss=1.3255  acc=0.5191  val_loss=1.8392  val_acc=0.4009
# Epoch  40/300  loss=1.3309  acc=0.5154  val_loss=1.8864  val_acc=0.4119
# Epoch  41/300  loss=1.3119  acc=0.5227  val_loss=1.8799  val_acc=0.4025
# Epoch  42/300  loss=1.3003  acc=0.5272  val_loss=1.8820  val_acc=0.4088
# Epoch  43/300  loss=1.3063  acc=0.5240  val_loss=1.9112  val_acc=0.3763
# Epoch  44/300  loss=1.2933  acc=0.5324  val_loss=1.9428  val_acc=0.4150
# Epoch  45/300  loss=1.2924  acc=0.5276  val_loss=1.9054  val_acc=0.4196
# Epoch  46/300  loss=1.2867  acc=0.5305  val_loss=2.0463  val_acc=0.4182
# Epoch  47/300  loss=1.2745  acc=0.5349  val_loss=1.9690  val_acc=0.4113
# Epoch  48/300  loss=1.2925  acc=0.5257  val_loss=2.0168  val_acc=0.3976
# Epoch  49/300  loss=1.2749  acc=0.5385  val_loss=1.9582  val_acc=0.3940
# Epoch  50/300  loss=1.2670  acc=0.5374  val_loss=1.9367  val_acc=0.4146
# Epoch  51/300  loss=1.2681  acc=0.5379  val_loss=1.9346  val_acc=0.4141
# Epoch  52/300  loss=1.2683  acc=0.5365  val_loss=1.9541  val_acc=0.4047
# Epoch  53/300  loss=1.2574  acc=0.5408  val_loss=2.0395  val_acc=0.4117
# Epoch  54/300  loss=1.2654  acc=0.5387  val_loss=2.0288  val_acc=0.4013
# Epoch  55/300  loss=1.2538  acc=0.5423  val_loss=1.9697  val_acc=0.4095
# Epoch  56/300  loss=1.2487  acc=0.5440  val_loss=1.9709  val_acc=0.3947
# Epoch  57/300  loss=1.2517  acc=0.5433  val_loss=2.0131  val_acc=0.4190
# Epoch  58/300  loss=1.2441  acc=0.5473  val_loss=2.1003  val_acc=0.4086
# Epoch  59/300  loss=1.2319  acc=0.5513  val_loss=2.0661  val_acc=0.3939
# Epoch  60/300  loss=1.2441  acc=0.5434  val_loss=2.0747  val_acc=0.3985
# Epoch  61/300  loss=1.2376  acc=0.5453  val_loss=2.0529  val_acc=0.4002
# Epoch  62/300  loss=1.2214  acc=0.5524  val_loss=2.1732  val_acc=0.4051
# Epoch  63/300  loss=1.2226  acc=0.5524  val_loss=2.0514  val_acc=0.4116
# Epoch  64/300  loss=1.2171  acc=0.5563  val_loss=2.1022  val_acc=0.4081
# Epoch  65/300  loss=1.2212  acc=0.5532  val_loss=2.0328  val_acc=0.4052
# Epoch  66/300  loss=1.2209  acc=0.5520  val_loss=2.1052  val_acc=0.4102
# Epoch  67/300  loss=1.2187  acc=0.5575  val_loss=2.1526  val_acc=0.4193
# Epoch  68/300  loss=1.2073  acc=0.5547  val_loss=2.1545  val_acc=0.4065
# Epoch  69/300  loss=1.2071  acc=0.5570  val_loss=1.9822  val_acc=0.3864
# Epoch  70/300  loss=1.2062  acc=0.5580  val_loss=2.1012  val_acc=0.4195
# Epoch  71/300  loss=1.2027  acc=0.5613  val_loss=2.2025  val_acc=0.4039
# Epoch  72/300  loss=1.2061  acc=0.5596  val_loss=2.1243  val_acc=0.3835
# Epoch  73/300  loss=1.2023  acc=0.5603  val_loss=2.1867  val_acc=0.4070
# Epoch  74/300  loss=1.1978  acc=0.5615  val_loss=2.2932  val_acc=0.4050
# Epoch  75/300  loss=1.1834  acc=0.5670  val_loss=2.2574  val_acc=0.3935
# Epoch  76/300  loss=1.2034  acc=0.5605  val_loss=2.1796  val_acc=0.3866
# Epoch  77/300  loss=1.1877  acc=0.5616  val_loss=2.2957  val_acc=0.4083
# Epoch  78/300  loss=1.1782  acc=0.5655  val_loss=2.2114  val_acc=0.3962
# Epoch  79/300  loss=1.1881  acc=0.5633  val_loss=2.2503  val_acc=0.3906
# Epoch  80/300  loss=1.1881  acc=0.5648  val_loss=2.2288  val_acc=0.3945
# Epoch  81/300  loss=1.1807  acc=0.5669  val_loss=2.1473  val_acc=0.4028
# Epoch  82/300  loss=1.1825  acc=0.5698  val_loss=2.3503  val_acc=0.4087
# Epoch  83/300  loss=1.1643  acc=0.5728  val_loss=2.1696  val_acc=0.4000
# Epoch  84/300  loss=1.1639  acc=0.5723  val_loss=2.3479  val_acc=0.4108
# Epoch  85/300  loss=1.1600  acc=0.5726  val_loss=2.2596  val_acc=0.4041
# Epoch  86/300  loss=1.1633  acc=0.5716  val_loss=2.1370  val_acc=0.3966
# Epoch  87/300  loss=1.1629  acc=0.5724  val_loss=2.3303  val_acc=0.3964
# Epoch  88/300  loss=1.1717  acc=0.5713  val_loss=2.2808  val_acc=0.3776
# Epoch  89/300  loss=1.1733  acc=0.5672  val_loss=2.2870  val_acc=0.4141
# Epoch  90/300  loss=1.1548  acc=0.5744  val_loss=2.3898  val_acc=0.4112
# Epoch  91/300  loss=1.1520  acc=0.5742  val_loss=2.3536  val_acc=0.3995
# Epoch  92/300  loss=1.1711  acc=0.5719  val_loss=2.4360  val_acc=0.4092
# Epoch  93/300  loss=1.1483  acc=0.5766  val_loss=2.3794  val_acc=0.3971
# Epoch  94/300  loss=1.1546  acc=0.5764  val_loss=2.3818  val_acc=0.4009
# Epoch  95/300  loss=1.1590  acc=0.5744  val_loss=2.4394  val_acc=0.4033
# Epoch  96/300  loss=1.1532  acc=0.5776  val_loss=2.3282  val_acc=0.3930
# Epoch  97/300  loss=1.1452  acc=0.5791  val_loss=2.3364  val_acc=0.3914
# Epoch  98/300  loss=1.1450  acc=0.5792  val_loss=2.4256  val_acc=0.4042
# Epoch  99/300  loss=1.1556  acc=0.5780  val_loss=2.2233  val_acc=0.3910
# Epoch 100/300  loss=1.1383  acc=0.5820  val_loss=2.3711  val_acc=0.4058
# Epoch 101/300  loss=1.1377  acc=0.5835  val_loss=2.3939  val_acc=0.4071
# Epoch 102/300  loss=1.1225  acc=0.5867  val_loss=2.4977  val_acc=0.3975
# Epoch 103/300  loss=1.1412  acc=0.5798  val_loss=2.3717  val_acc=0.4070
# Epoch 104/300  loss=1.1312  acc=0.5819  val_loss=2.4423  val_acc=0.4066
# Epoch 105/300  loss=1.1423  acc=0.5814  val_loss=2.3317  val_acc=0.3995
# Epoch 106/300  loss=1.1323  acc=0.5819  val_loss=2.4891  val_acc=0.4092
# Epoch 107/300  loss=1.1544  acc=0.5780  val_loss=2.3214  val_acc=0.3808
# Epoch 108/300  loss=1.1291  acc=0.5849  val_loss=2.5910  val_acc=0.3936
# Epoch 109/300  loss=1.1279  acc=0.5857  val_loss=2.4731  val_acc=0.3815
# Epoch 110/300  loss=1.1574  acc=0.5742  val_loss=2.5020  val_acc=0.3996
# Epoch 111/300  loss=1.1224  acc=0.5897  val_loss=2.3971  val_acc=0.4030
# Epoch 112/300  loss=1.1232  acc=0.5859  val_loss=2.5374  val_acc=0.4069
# Epoch 113/300  loss=1.1153  acc=0.5877  val_loss=2.5892  val_acc=0.3864
# Epoch 114/300  loss=1.1086  acc=0.5913  val_loss=2.4418  val_acc=0.4020
# Epoch 115/300  loss=1.0828  acc=0.5956  val_loss=2.7149  val_acc=0.4053
# Epoch 116/300  loss=1.1173  acc=0.5897  val_loss=2.7057  val_acc=0.3995
# Epoch 117/300  loss=1.1287  acc=0.5871  val_loss=2.4713  val_acc=0.4126
# Epoch 118/300  loss=1.0973  acc=0.5956  val_loss=2.6108  val_acc=0.3827
# Epoch 119/300  loss=1.1185  acc=0.5874  val_loss=2.6899  val_acc=0.4090
# Epoch 120/300  loss=1.1224  acc=0.5923  val_loss=2.5260  val_acc=0.3846
# Epoch 121/300  loss=1.1035  acc=0.5945  val_loss=2.6241  val_acc=0.3994
# Epoch 122/300  loss=1.1036  acc=0.5925  val_loss=2.4962  val_acc=0.3972
# Epoch 123/300  loss=1.1353  acc=0.5840  val_loss=2.5436  val_acc=0.4085
# Epoch 124/300  loss=1.0979  acc=0.5957  val_loss=2.6568  val_acc=0.3961
# Epoch 125/300  loss=1.1083  acc=0.5889  val_loss=2.5674  val_acc=0.4123
# Epoch 126/300  loss=1.0865  acc=0.6001  val_loss=2.8274  val_acc=0.3631
# Epoch 127/300  loss=1.1148  acc=0.5920  val_loss=2.5776  val_acc=0.3956
# Epoch 128/300  loss=1.0936  acc=0.5933  val_loss=2.5916  val_acc=0.4061
# Epoch 129/300  loss=1.1323  acc=0.5854  val_loss=2.5845  val_acc=0.4035
# Epoch 130/300  loss=1.0905  acc=0.5988  val_loss=2.7833  val_acc=0.3945
# Epoch 131/300  loss=1.0893  acc=0.5952  val_loss=2.7631  val_acc=0.4055
# Epoch 132/300  loss=1.1188  acc=0.5900  val_loss=2.7237  val_acc=0.3852
# Epoch 133/300  loss=1.0706  acc=0.6009  val_loss=2.7753  val_acc=0.4058
# Epoch 134/300  loss=1.1145  acc=0.5906  val_loss=2.6160  val_acc=0.3979
# Epoch 135/300  loss=1.0990  acc=0.5958  val_loss=2.7922  val_acc=0.3928
# Epoch 136/300  loss=1.1150  acc=0.5901  val_loss=2.6081  val_acc=0.3911
# Epoch 137/300  loss=1.1060  acc=0.5947  val_loss=2.8221  val_acc=0.4065
# Epoch 138/300  loss=1.0712  acc=0.6044  val_loss=2.5457  val_acc=0.4035
# Epoch 139/300  loss=1.0968  acc=0.5972  val_loss=2.6290  val_acc=0.3940
# Epoch 140/300  loss=1.0745  acc=0.6031  val_loss=2.7939  val_acc=0.3851
# Epoch 141/300  loss=1.0959  acc=0.5947  val_loss=2.5826  val_acc=0.4034
# Epoch 142/300  loss=1.0776  acc=0.6020  val_loss=2.5873  val_acc=0.4060
# Epoch 143/300  loss=1.1154  acc=0.5923  val_loss=2.5317  val_acc=0.3880
# Epoch 144/300  loss=1.0856  acc=0.5992  val_loss=2.6622  val_acc=0.4105
# Epoch 145/300  loss=1.0752  acc=0.6057  val_loss=2.7101  val_acc=0.4039
# Epoch 146/300  loss=1.0851  acc=0.6003  val_loss=2.9867  val_acc=0.3959
# Epoch 147/300  loss=1.1092  acc=0.5916  val_loss=2.6493  val_acc=0.4039
# Epoch 148/300  loss=1.0766  acc=0.6014  val_loss=2.8297  val_acc=0.4084
# Epoch 149/300  loss=1.0669  acc=0.6022  val_loss=2.6616  val_acc=0.3793
# Epoch 150/300  loss=1.0586  acc=0.6075  val_loss=2.6749  val_acc=0.3828
# Epoch 151/300  loss=1.0803  acc=0.5987  val_loss=2.9167  val_acc=0.3916
# Epoch 152/300  loss=1.0684  acc=0.6028  val_loss=2.7497  val_acc=0.3877
# Epoch 153/300  loss=1.0861  acc=0.6023  val_loss=2.7943  val_acc=0.3940
# Epoch 154/300  loss=1.0706  acc=0.6033  val_loss=2.8409  val_acc=0.4092
# Epoch 155/300  loss=1.0813  acc=0.5999  val_loss=2.8126  val_acc=0.3877
# Epoch 156/300  loss=1.0910  acc=0.6000  val_loss=2.7541  val_acc=0.3941
# Epoch 157/300  loss=1.0612  acc=0.6075  val_loss=2.7772  val_acc=0.3911
# Epoch 158/300  loss=1.0891  acc=0.6035  val_loss=2.7697  val_acc=0.3920
# Epoch 159/300  loss=1.0569  acc=0.6064  val_loss=2.9360  val_acc=0.3973
# Epoch 160/300  loss=1.0457  acc=0.6092  val_loss=3.0568  val_acc=0.4107
# Epoch 161/300  loss=1.0937  acc=0.6001  val_loss=2.9176  val_acc=0.4095
# Epoch 162/300  loss=1.0625  acc=0.6078  val_loss=2.6226  val_acc=0.4009
# Epoch 163/300  loss=1.0553  acc=0.6052  val_loss=2.9335  val_acc=0.4036
# Epoch 164/300  loss=1.0546  acc=0.6091  val_loss=2.7540  val_acc=0.4082
# Epoch 165/300  loss=1.0649  acc=0.6045  val_loss=2.7007  val_acc=0.4065
# Epoch 166/300  loss=1.0557  acc=0.6087  val_loss=2.7864  val_acc=0.3966
# Epoch 167/300  loss=1.0424  acc=0.6115  val_loss=3.1272  val_acc=0.4095
# Epoch 168/300  loss=1.0744  acc=0.6042  val_loss=3.0263  val_acc=0.4067
# Epoch 169/300  loss=1.0617  acc=0.6060  val_loss=2.9418  val_acc=0.3927
# Epoch 170/300  loss=1.0675  acc=0.6063  val_loss=2.8749  val_acc=0.3836
# Epoch 171/300  loss=1.0567  acc=0.6096  val_loss=2.6102  val_acc=0.3660
# Epoch 172/300  loss=1.0621  acc=0.6078  val_loss=2.9202  val_acc=0.4022
# Epoch 173/300  loss=1.0632  acc=0.6069  val_loss=2.7220  val_acc=0.3965
# Epoch 174/300  loss=1.0498  acc=0.6087  val_loss=3.0749  val_acc=0.4035
# Epoch 175/300  loss=1.0598  acc=0.6051  val_loss=3.0613  val_acc=0.3840
# Epoch 176/300  loss=1.0684  acc=0.6058  val_loss=2.9032  val_acc=0.3941
# Epoch 177/300  loss=1.0711  acc=0.6053  val_loss=2.9225  val_acc=0.3987
# Epoch 178/300  loss=1.0566  acc=0.6095  val_loss=2.8355  val_acc=0.3762
# Epoch 179/300  loss=1.0559  acc=0.6098  val_loss=2.9424  val_acc=0.3885
# Epoch 180/300  loss=1.0663  acc=0.6097  val_loss=3.3607  val_acc=0.4049
# Epoch 181/300  loss=1.0563  acc=0.6097  val_loss=3.2534  val_acc=0.4081
# Epoch 182/300  loss=1.0624  acc=0.6087  val_loss=2.8502  val_acc=0.3894
# Epoch 183/300  loss=1.0514  acc=0.6091  val_loss=3.0068  val_acc=0.3991
# Epoch 184/300  loss=1.0501  acc=0.6141  val_loss=3.1097  val_acc=0.4006
# Epoch 185/300  loss=1.0566  acc=0.6107  val_loss=3.0825  val_acc=0.3853
# Epoch 186/300  loss=1.0519  acc=0.6122  val_loss=3.0752  val_acc=0.3975
# Epoch 187/300  loss=1.0698  acc=0.6071  val_loss=2.9317  val_acc=0.3986
# Epoch 188/300  loss=1.0418  acc=0.6146  val_loss=3.0763  val_acc=0.3903
# Epoch 189/300  loss=1.0833  acc=0.6031  val_loss=2.9374  val_acc=0.3762
# Epoch 190/300  loss=1.0637  acc=0.6119  val_loss=2.9545  val_acc=0.3965
# Epoch 191/300  loss=1.0198  acc=0.6191  val_loss=3.2369  val_acc=0.4073
# Epoch 192/300  loss=1.0613  acc=0.6087  val_loss=3.1906  val_acc=0.4022
# Epoch 193/300  loss=1.0527  acc=0.6103  val_loss=2.8827  val_acc=0.3978
# Epoch 194/300  loss=1.0287  acc=0.6173  val_loss=3.1045  val_acc=0.3861
# Epoch 195/300  loss=1.0495  acc=0.6120  val_loss=3.2565  val_acc=0.3972
# Epoch 196/300  loss=1.0376  acc=0.6148  val_loss=3.2788  val_acc=0.3770
# Epoch 197/300  loss=1.0530  acc=0.6116  val_loss=3.2062  val_acc=0.4009
# Epoch 198/300  loss=1.0478  acc=0.6165  val_loss=3.1765  val_acc=0.4095
# Epoch 199/300  loss=1.0306  acc=0.6164  val_loss=3.0899  val_acc=0.3679
# Epoch 200/300  loss=1.0327  acc=0.6177  val_loss=2.9944  val_acc=0.3960
# Epoch 201/300  loss=1.0508  acc=0.6139  val_loss=3.1171  val_acc=0.4085
# Epoch 202/300  loss=1.0686  acc=0.6061  val_loss=3.0843  val_acc=0.3994
# Epoch 203/300  loss=1.0291  acc=0.6178  val_loss=3.2844  val_acc=0.3931
# Epoch 204/300  loss=1.0296  acc=0.6188  val_loss=2.9093  val_acc=0.3887
# Epoch 205/300  loss=1.1076  acc=0.6016  val_loss=3.0160  val_acc=0.3948
# Epoch 206/300  loss=1.0225  acc=0.6213  val_loss=3.2465  val_acc=0.3881
# Epoch 207/300  loss=1.0235  acc=0.6207  val_loss=3.2626  val_acc=0.3918
# Epoch 208/300  loss=1.0412  acc=0.6156  val_loss=3.0912  val_acc=0.4027
# Epoch 209/300  loss=1.0193  acc=0.6217  val_loss=3.2042  val_acc=0.3880
# Epoch 210/300  loss=1.0806  acc=0.6056  val_loss=3.2359  val_acc=0.4043
# Epoch 211/300  loss=1.0239  acc=0.6208  val_loss=3.1451  val_acc=0.3943
# Epoch 212/300  loss=1.0181  acc=0.6213  val_loss=3.1941  val_acc=0.3917
# Epoch 213/300  loss=1.0249  acc=0.6197  val_loss=3.2794  val_acc=0.3902
# Epoch 214/300  loss=1.0379  acc=0.6143  val_loss=3.1165  val_acc=0.3925
# Epoch 215/300  loss=1.0318  acc=0.6197  val_loss=3.3938  val_acc=0.3836
# Epoch 216/300  loss=1.0316  acc=0.6197  val_loss=3.4436  val_acc=0.3965
# Epoch 217/300  loss=1.0419  acc=0.6139  val_loss=3.0941  val_acc=0.3830
# Epoch 218/300  loss=1.0246  acc=0.6222  val_loss=3.0329  val_acc=0.3882
# Epoch 219/300  loss=1.0286  acc=0.6197  val_loss=3.4132  val_acc=0.3946
# Epoch 220/300  loss=1.0049  acc=0.6279  val_loss=3.2214  val_acc=0.3929
# Epoch 221/300  loss=1.0435  acc=0.6117  val_loss=3.3474  val_acc=0.3894
# Epoch 222/300  loss=1.0360  acc=0.6149  val_loss=3.1600  val_acc=0.3719
# Epoch 223/300  loss=1.0331  acc=0.6159  val_loss=3.3746  val_acc=0.3960
# Epoch 224/300  loss=1.0063  acc=0.6247  val_loss=3.1606  val_acc=0.4050
# Epoch 225/300  loss=1.0690  acc=0.6078  val_loss=3.0671  val_acc=0.3747
# Epoch 226/300  loss=1.0550  acc=0.6121  val_loss=3.3466  val_acc=0.3948
# Epoch 227/300  loss=0.9960  acc=0.6264  val_loss=3.5820  val_acc=0.3915
# Epoch 228/300  loss=1.0334  acc=0.6187  val_loss=3.1498  val_acc=0.4022
# Epoch 229/300  loss=1.0635  acc=0.6118  val_loss=3.1914  val_acc=0.3929
# Epoch 230/300  loss=1.0038  acc=0.6254  val_loss=3.7562  val_acc=0.3996
# Epoch 231/300  loss=1.0082  acc=0.6281  val_loss=3.7774  val_acc=0.3989
# Epoch 232/300  loss=1.0269  acc=0.6171  val_loss=3.3500  val_acc=0.4025
# Epoch 233/300  loss=1.0360  acc=0.6181  val_loss=3.1816  val_acc=0.3880
# Epoch 234/300  loss=1.0290  acc=0.6209  val_loss=3.7746  val_acc=0.4018
# Epoch 235/300  loss=1.0340  acc=0.6209  val_loss=3.2861  val_acc=0.3974
# Epoch 236/300  loss=1.0211  acc=0.6214  val_loss=3.3135  val_acc=0.4034
# Epoch 237/300  loss=1.0065  acc=0.6247  val_loss=3.2505  val_acc=0.3859
# Epoch 238/300  loss=1.0181  acc=0.6222  val_loss=3.4475  val_acc=0.3875
# Epoch 239/300  loss=1.0290  acc=0.6246  val_loss=3.3524  val_acc=0.3791
# Epoch 240/300  loss=1.0381  acc=0.6196  val_loss=3.5259  val_acc=0.3958
# Epoch 241/300  loss=1.0148  acc=0.6257  val_loss=3.0946  val_acc=0.3937
# Epoch 242/300  loss=1.0203  acc=0.6260  val_loss=3.2525  val_acc=0.3876
# Epoch 243/300  loss=1.0124  acc=0.6234  val_loss=3.3873  val_acc=0.3893
# Epoch 244/300  loss=1.0390  acc=0.6159  val_loss=3.4369  val_acc=0.3921
# Epoch 245/300  loss=1.0702  acc=0.6090  val_loss=3.4779  val_acc=0.3896
# Epoch 246/300  loss=1.0317  acc=0.6205  val_loss=3.2886  val_acc=0.3901
# Epoch 247/300  loss=1.0030  acc=0.6288  val_loss=3.6062  val_acc=0.4030
# Epoch 248/300  loss=1.0261  acc=0.6205  val_loss=3.5257  val_acc=0.3932
# Epoch 249/300  loss=0.9913  acc=0.6292  val_loss=3.5935  val_acc=0.4000
# Epoch 250/300  loss=1.0191  acc=0.6224  val_loss=3.2752  val_acc=0.3724
# Epoch 251/300  loss=1.0380  acc=0.6182  val_loss=3.6233  val_acc=0.4086
# Epoch 252/300  loss=1.0062  acc=0.6272  val_loss=3.5240  val_acc=0.3875
# Epoch 253/300  loss=1.0617  acc=0.6173  val_loss=3.4309  val_acc=0.3860
# Epoch 254/300  loss=1.0290  acc=0.6206  val_loss=3.5083  val_acc=0.3967
# Epoch 255/300  loss=1.0112  acc=0.6255  val_loss=3.3472  val_acc=0.3834
# Epoch 256/300  loss=1.0169  acc=0.6249  val_loss=3.2788  val_acc=0.3829
# Epoch 257/300  loss=1.0374  acc=0.6207  val_loss=3.3450  val_acc=0.3818
# Epoch 258/300  loss=0.9894  acc=0.6274  val_loss=3.4402  val_acc=0.3687
# Epoch 259/300  loss=1.0400  acc=0.6184  val_loss=3.6326  val_acc=0.3983
# Epoch 260/300  loss=1.0034  acc=0.6264  val_loss=3.5611  val_acc=0.3766
# Epoch 261/300  loss=1.0071  acc=0.6294  val_loss=3.5825  val_acc=0.4001
# Epoch 262/300  loss=1.0371  acc=0.6211  val_loss=3.8637  val_acc=0.4003
# Epoch 263/300  loss=1.0233  acc=0.6230  val_loss=3.3212  val_acc=0.4072
# Epoch 264/300  loss=0.9997  acc=0.6309  val_loss=3.5690  val_acc=0.3939
# Epoch 265/300  loss=0.9931  acc=0.6271  val_loss=3.1623  val_acc=0.3862
# Epoch 266/300  loss=1.0295  acc=0.6190  val_loss=3.3259  val_acc=0.3807
# Epoch 267/300  loss=0.9983  acc=0.6276  val_loss=3.8825  val_acc=0.4022
# Epoch 268/300  loss=1.0667  acc=0.6118  val_loss=3.5906  val_acc=0.3920
# Epoch 269/300  loss=0.9932  acc=0.6329  val_loss=3.6263  val_acc=0.4039
# Epoch 270/300  loss=1.0034  acc=0.6276  val_loss=3.6482  val_acc=0.3927
# Epoch 271/300  loss=1.0159  acc=0.6257  val_loss=3.3898  val_acc=0.3948
# Epoch 272/300  loss=0.9842  acc=0.6350  val_loss=3.7779  val_acc=0.4001
# Epoch 273/300  loss=1.0404  acc=0.6184  val_loss=3.1074  val_acc=0.3806
# Epoch 274/300  loss=1.0447  acc=0.6166  val_loss=3.7747  val_acc=0.3961
# Epoch 275/300  loss=0.9945  acc=0.6309  val_loss=3.5976  val_acc=0.3911
# Epoch 276/300  loss=1.0095  acc=0.6303  val_loss=3.3030  val_acc=0.3742
# Epoch 277/300  loss=1.0203  acc=0.6217  val_loss=3.3983  val_acc=0.3865
# Epoch 278/300  loss=1.0122  acc=0.6264  val_loss=3.4196  val_acc=0.3910
# Epoch 279/300  loss=1.0528  acc=0.6134  val_loss=3.3308  val_acc=0.3823
# Epoch 280/300  loss=0.9878  acc=0.6345  val_loss=3.3999  val_acc=0.3860
# Epoch 281/300  loss=1.0203  acc=0.6279  val_loss=3.2130  val_acc=0.3713
# Epoch 282/300  loss=1.0033  acc=0.6299  val_loss=3.5981  val_acc=0.3817
# Epoch 283/300  loss=0.9895  acc=0.6305  val_loss=3.8236  val_acc=0.3851
# Epoch 284/300  loss=1.0673  acc=0.6122  val_loss=3.4077  val_acc=0.3793
# Epoch 285/300  loss=1.0010  acc=0.6303  val_loss=3.5112  val_acc=0.4040
# Epoch 286/300  loss=1.0021  acc=0.6296  val_loss=3.6723  val_acc=0.3795
# Epoch 287/300  loss=1.0247  acc=0.6255  val_loss=3.6695  val_acc=0.3938
# Epoch 288/300  loss=0.9745  acc=0.6350  val_loss=3.7037  val_acc=0.3885
# Epoch 289/300  loss=1.0331  acc=0.6275  val_loss=3.4378  val_acc=0.3752
# Epoch 290/300  loss=1.0331  acc=0.6239  val_loss=3.6138  val_acc=0.3859
# Epoch 291/300  loss=0.9852  acc=0.6327  val_loss=3.9068  val_acc=0.3889
# Epoch 292/300  loss=0.9888  acc=0.6346  val_loss=3.8555  val_acc=0.4008
# Epoch 293/300  loss=0.9990  acc=0.6295  val_loss=3.5198  val_acc=0.4039
# Epoch 294/300  loss=1.0164  acc=0.6257  val_loss=3.7994  val_acc=0.3816
# Epoch 295/300  loss=1.0082  acc=0.6280  val_loss=3.8201  val_acc=0.3876
# Epoch 296/300  loss=1.0392  acc=0.6206  val_loss=3.4286  val_acc=0.3873
# Epoch 297/300  loss=1.0041  acc=0.6304  val_loss=3.6172  val_acc=0.3807
# Epoch 298/300  loss=0.9996  acc=0.6320  val_loss=4.1390  val_acc=0.4004
# Epoch 299/300  loss=1.0150  acc=0.6299  val_loss=3.8103  val_acc=0.3884
# Epoch 300/300  loss=1.0173  acc=0.6251  val_loss=3.3525  val_acc=0.3941

# %%
# Utiliser notre fonction plot_training_history pour afficher l'évolution de la fonction de coût
plot_training_history(history)

# %%
evaluate(mlp_trained, train_set_reduit)   # train réduit
evaluate(mlp_trained, train_full) # train complet
evaluate(mlp_trained, test_set)       # test
# Out:
# loss=0.9335  accuracy=0.6460
# loss=1.4173  accuracy=0.5956
# loss=3.2559  accuracy=0.3932
# (3.255919575881958, 0.3932)

# %%
index_img = 205
img, label = test_set[index_img]   # déballage correct : img (3,32,32) + label int
model_predict(mlp_trained, img, label)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9529412..0.937255].
# The image is a      : cat
# The model predicted : dog

# %% [markdown]
# ### <font color='blue'> Definir un CNN

# %%
# premier modèle CNN
# Definir le model
class CNN_MODEL(nn.Module):
    def __init__(self,
                 in_channels: int = 1,
                 input_size: tuple = (28, 28),
                 num_classes: int = 10) -> None:
        super().__init__()

        self.feature_extractor = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=6, kernel_size=5),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=2, stride=2),

            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=2, stride=2),
        )

        # Inférence automatique de la taille aplatie
        # On fait passer un tenseur factice pour connaître la forme de sortie
        # sans avoir à la calculer à la main selon la résolution d'entrée.
        dummy = torch.zeros(1, in_channels, *input_size)
        flat_size = self.feature_extractor(dummy).numel()

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(flat_size, 120),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(84, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.feature_extractor(x)
        x = self.classifier(x)
        return x

# %%
# Verifier le model
model_cnn = CNN_MODEL(3, (32, 32))
print(model_cnn)

n_params = sum(p.numel() for p in model_cnn.parameters() if p.requires_grad)
print(f'\nParamètres entraînables : {n_params:,}')
# Out:
# CNN_MODEL(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=400, out_features=120, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=120, out_features=84, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.2, inplace=False)
#     (7): Linear(in_features=84, out_features=10, bias=True)
#   )
# )
#
# Paramètres entraînables : 62,006

# %% [markdown]
# ### <font color='blue'> Entrainer et evaluer le modèle </font>

# %%
# Entrainement du modèle
# Entrainer le modèle
nombre_epochs =300
batch_size = 34
lr = 0.001
cnn_trained, history_cnn= train_net(model_cnn, train_set_reduit, val_set, nombre_epochs, lr, batch_size, None)
# Out:
# Using mps device
# Epoch   1/300  loss=1.8548  acc=0.3070  val_loss=1.6232  val_acc=0.4080
# Epoch   2/300  loss=1.5749  acc=0.4277  val_loss=1.4615  val_acc=0.4698
# Epoch   3/300  loss=1.4811  acc=0.4651  val_loss=1.3664  val_acc=0.5015
# Epoch   4/300  loss=1.4033  acc=0.4969  val_loss=1.3281  val_acc=0.5207
# Epoch   5/300  loss=1.3635  acc=0.5115  val_loss=1.2868  val_acc=0.5361
# Epoch   6/300  loss=1.3217  acc=0.5286  val_loss=1.2783  val_acc=0.5399
# Epoch   7/300  loss=1.2924  acc=0.5402  val_loss=1.2593  val_acc=0.5470
# Epoch   8/300  loss=1.2641  acc=0.5518  val_loss=1.2142  val_acc=0.5692
# Epoch   9/300  loss=1.2377  acc=0.5595  val_loss=1.2193  val_acc=0.5653
# Epoch  10/300  loss=1.2140  acc=0.5701  val_loss=1.2325  val_acc=0.5634
# Epoch  11/300  loss=1.1987  acc=0.5734  val_loss=1.2337  val_acc=0.5634

# %%
# Utiliser notre fonction plot_training_history pour afficher l'évolution de la fonction de coût
plot_training_history(history_cnn)

# %%
evaluate(mlp_trained, train_set_reduit)   # train réduit
evaluate(mlp_trained, train_full) # train complet
evaluate(mlp_trained, test_set)       # test
# Out:
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.6893 - accuracy: 0.7551
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.6893 - accuracy: 0.7551
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2105 - accuracy: 0.6201
# [1.2105045318603516, 0.6201000213623047]
